# %% [markdown]
# # Parameter study for Pipeline Transport, Gas Quality, and Linepack
#
#     This notebook regenerates the parameter-study table and figure embedded in the
#     chapter. It is intentionally lightweight so PaperLab can refresh the visible
#     results while the full companion notebook remains available for broader
#     branch-specific NeqSim workflows.

# %%
from pathlib import Path
import json

import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

NOTEBOOK_DIR = Path(globals().get("__vsc_ipynb_file__", "expected_output.ipynb")).resolve().parent
FIGURES_DIR = NOTEBOOK_DIR.parent / "figures"
FIGURES_DIR.mkdir(exist_ok=True)

headers = ["Length (km)", "Pressure (bara)", "Temperature (degC)", "Linepack index"]
rows = [[0, 150.0, 20.0, 1.0], [100, 138.0, 13.5, 0.93], [250, 119.0, 8.5, 0.8], [400, 101.0, 6.2, 0.68], [500, 90.0, 5.5, 0.6]]
series = [["Pressure", [150.0, 138.0, 119.0, 101.0, 90.0]], ["Temperature x5", [100.0, 67.5, 42.5, 31.0, 27.5]]]
study = {"caption": "Expected hydrogen pipeline pressure and temperature profile.", "description": "The pipeline notebook should produce a profile, not just an outlet pressure. The expected output shows pressure loss over distance and cooling toward the specified surface-temperature basis.", "discussion": "The parameter study shows how long-distance compressed hydrogen export after compression responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where outlet pressure, outlet temperature, pressure profile, temperature profile, pressure drop, Wobbe index, relative density, and linepack begin to trade against margin or cost.", "calculation_basis": "Isentropic compression, intercooling heat balance, pipeline pressure-profile, temperature-profile, and linepack inventory calculations.", "study_basis": "GPSA and gas-transmission references provide independent engineering ranges for compression, transport, and gas-quality interpretation.", "source_labels": "GPSA engineering data reference, Gas transmission and processing reference, Chemical engineering design reference", "citation": "\\cite{gpsa2012,mokhatab2018,towler2013chemical}"}
topic_examples = []
df = pd.DataFrame(rows, columns=headers)
display(df)
df.to_csv(FIGURES_DIR / "notebook_pipeline_profile_output.csv", index=False)
if topic_examples:
    topic_df = pd.DataFrame(topic_examples)
    display(topic_df[["route", "number", "topic", "calculation", "sweep", "kpis", "source_labels"]])
    topic_df.to_csv(FIGURES_DIR / "notebook_pipeline_profile_output_topic_examples.csv", index=False)

# %%
plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "legend.fontsize": 8,
    "figure.dpi": 150,
    "savefig.dpi": 150,
    "axes.grid": True,
    "grid.alpha": 0.35,
})

x = list(df[headers[0]])
fig, ax = plt.subplots(figsize=(7.0, 4.0))
for name, values in series:
    ax.plot(x, values, marker="o", linewidth=1.8, label=name)
ax.set_xlabel("Length (km)")
ax.set_ylabel("Pressure (bara) / temperature (degC)")
ax.set_title("Expected hydrogen pipeline pressure and temperature profile.")
ax.legend(frameon=False)
fig.tight_layout()
fig.savefig(FIGURES_DIR / "notebook_pipeline_profile_output.png", dpi=150, bbox_inches="tight")
plt.show()
print("wrote", FIGURES_DIR / "notebook_pipeline_profile_output.png")

# %% [markdown]
# ## Results and discussion
#
# The pipeline notebook should produce a profile, not just an outlet pressure. The expected output shows pressure loss over distance and cooling toward the specified surface-temperature basis.
#
# **Calculation basis.** Isentropic compression, intercooling heat balance, pipeline pressure-profile, temperature-profile, and linepack inventory calculations.
#
# **Study basis.** GPSA and gas-transmission references provide independent engineering ranges for compression, transport, and gas-quality interpretation. \cite{gpsa2012,mokhatab2018,towler2013chemical}
#
# **Discussion.** The parameter study shows how long-distance compressed hydrogen export after compression responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where outlet pressure, outlet temperature, pressure profile, temperature profile, pressure drop, Wobbe index, relative density, and linepack begin to trade against margin or cost.

# %%
result = {
    "chapter": "ch15_pipeline_transport_linepack",
    "title": "Pipeline Transport, Gas Quality, and Linepack",
    "figure": "notebook_pipeline_profile_output.png",
    "caption": "Expected hydrogen pipeline pressure and temperature profile.",
    "description": "The pipeline notebook should produce a profile, not just an outlet pressure. The expected output shows pressure loss over distance and cooling toward the specified surface-temperature basis.",
    "discussion": "The parameter study shows how long-distance compressed hydrogen export after compression responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where outlet pressure, outlet temperature, pressure profile, temperature profile, pressure drop, Wobbe index, relative density, and linepack begin to trade against margin or cost.",
    "calculation_basis": "Isentropic compression, intercooling heat balance, pipeline pressure-profile, temperature-profile, and linepack inventory calculations.",
    "study_basis": "GPSA and gas-transmission references provide independent engineering ranges for compression, transport, and gas-quality interpretation.",
    "source_labels": "GPSA engineering data reference, Gas transmission and processing reference, Chemical engineering design reference",
    "citation": "\\cite{gpsa2012,mokhatab2018,towler2013chemical}",
    "topic_examples": topic_examples,
    "rows": df.to_dict(orient="records"),
}
with open(FIGURES_DIR / "notebook_pipeline_profile_output_results.json", "w", encoding="utf-8") as handle:
    json.dump(result, handle, indent=2)
result
