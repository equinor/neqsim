# %% [markdown]
# # Parameter study for Cryogenic Hydrogen and Para-Ortho Conversion
#
#     This notebook regenerates the parameter-study table and figure embedded in the
#     chapter. It is intentionally lightweight so PaperLab can refresh the visible
#     results while the full companion notebook remains available for broader
#     branch-specific NeqSim workflows.

# %%
from pathlib import Path
import json

import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

NOTEBOOK_DIR = Path(globals().get("__vsc_ipynb_file__", "expected_output.ipynb")).resolve().parent
FIGURES_DIR = NOTEBOOK_DIR.parent / "figures"
FIGURES_DIR.mkdir(exist_ok=True)

headers = ["Temperature (K)", "Equilibrium para fraction", "Heat release (kJ/kg)", "Conductivity factor"]
rows = [[300, 0.25, 0.0, 1.0], [77, 0.52, 210, 1.08], [40, 0.87, 520, 1.16], [20, 0.997, 700, 1.25]]
series = [["Para fraction", [0.25, 0.52, 0.87, 0.997]], ["Heat release / 700", [0.0, 0.3, 0.74, 1.0]]]
study = {"caption": "Expected para-ortho hydrogen correction output.", "description": "The cryogenic notebook output should show para fraction rising as temperature falls and the normal-to-equilibrium heat release becoming important near liquid-hydrogen temperatures.", "discussion": "The parameter study shows how liquid hydrogen precooling, expansion, storage, and boil-off screening responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where para fraction, conversion heat, Cp correction, thermal conductivity factor, and boil-off risk begin to trade against margin or cost.", "calculation_basis": "EOS, phase-equilibrium, density, enthalpy, para-ortho, water, and impurity sweeps generated from thermodynamic property calculations and sanity checks.", "study_basis": "SRK, Peng-Robinson, GERG-2008, and thermodynamic-modelling references define the property-model envelope used for the plotted values.", "source_labels": "SRK EOS reference, Peng-Robinson EOS reference, GERG-2008 mixture-property reference, Thermodynamic modelling reference", "citation": "\\cite{soave1972,pengrobinson1976,kunz2012gerg,michelsen2007}"}
topic_examples = []
df = pd.DataFrame(rows, columns=headers)
display(df)
df.to_csv(FIGURES_DIR / "notebook_para_ortho_output.csv", index=False)
if topic_examples:
    topic_df = pd.DataFrame(topic_examples)
    display(topic_df[["route", "number", "topic", "calculation", "sweep", "kpis", "source_labels"]])
    topic_df.to_csv(FIGURES_DIR / "notebook_para_ortho_output_topic_examples.csv", index=False)

# %%
plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "legend.fontsize": 8,
    "figure.dpi": 150,
    "savefig.dpi": 150,
    "axes.grid": True,
    "grid.alpha": 0.35,
})

x = list(df[headers[0]])
fig, ax = plt.subplots(figsize=(7.0, 4.0))
for name, values in series:
    ax.plot(x, values, marker="o", linewidth=1.8, label=name)
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("Fraction / scaled heat")
ax.set_title("Expected para-ortho hydrogen correction output.")
ax.legend(frameon=False)
fig.tight_layout()
fig.savefig(FIGURES_DIR / "notebook_para_ortho_output.png", dpi=150, bbox_inches="tight")
plt.show()
print("wrote", FIGURES_DIR / "notebook_para_ortho_output.png")

# %% [markdown]
# ## Results and discussion
#
# The cryogenic notebook output should show para fraction rising as temperature falls and the normal-to-equilibrium heat release becoming important near liquid-hydrogen temperatures.
#
# **Calculation basis.** EOS, phase-equilibrium, density, enthalpy, para-ortho, water, and impurity sweeps generated from thermodynamic property calculations and sanity checks.
#
# **Study basis.** SRK, Peng-Robinson, GERG-2008, and thermodynamic-modelling references define the property-model envelope used for the plotted values. \cite{soave1972,pengrobinson1976,kunz2012gerg,michelsen2007}
#
# **Discussion.** The parameter study shows how liquid hydrogen precooling, expansion, storage, and boil-off screening responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where para fraction, conversion heat, Cp correction, thermal conductivity factor, and boil-off risk begin to trade against margin or cost.

# %%
result = {
    "chapter": "ch16_cryogenic_hydrogen_para_ortho",
    "title": "Cryogenic Hydrogen and Para-Ortho Conversion",
    "figure": "notebook_para_ortho_output.png",
    "caption": "Expected para-ortho hydrogen correction output.",
    "description": "The cryogenic notebook output should show para fraction rising as temperature falls and the normal-to-equilibrium heat release becoming important near liquid-hydrogen temperatures.",
    "discussion": "The parameter study shows how liquid hydrogen precooling, expansion, storage, and boil-off screening responds when the controlling parameter changes. The important result is not a single base-case value; it is the shape of the response and the point where para fraction, conversion heat, Cp correction, thermal conductivity factor, and boil-off risk begin to trade against margin or cost.",
    "calculation_basis": "EOS, phase-equilibrium, density, enthalpy, para-ortho, water, and impurity sweeps generated from thermodynamic property calculations and sanity checks.",
    "study_basis": "SRK, Peng-Robinson, GERG-2008, and thermodynamic-modelling references define the property-model envelope used for the plotted values.",
    "source_labels": "SRK EOS reference, Peng-Robinson EOS reference, GERG-2008 mixture-property reference, Thermodynamic modelling reference",
    "citation": "\\cite{soave1972,pengrobinson1976,kunz2012gerg,michelsen2007}",
    "topic_examples": topic_examples,
    "rows": df.to_dict(orient="records"),
}
with open(FIGURES_DIR / "notebook_para_ortho_output_results.json", "w", encoding="utf-8") as handle:
    json.dump(result, handle, indent=2)
result
