# %% [markdown]
# # Parameter study for Optimization, Automation API, and Digital Twins
#
#     This notebook regenerates the parameter-study table and figure embedded in the
#     chapter. It is intentionally lightweight so PaperLab can refresh the visible
#     results while the full companion notebook remains available for broader
#     branch-specific NeqSim workflows.

# %%
from pathlib import Path
import json

import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

NOTEBOOK_DIR = Path(globals().get("__vsc_ipynb_file__", "expected_output.ipynb")).resolve().parent
FIGURES_DIR = NOTEBOOK_DIR.parent / "figures"
FIGURES_DIR.mkdir(exist_ok=True)

headers = ["Scenario count", "Envelope coverage", "Runtime index", "Decision confidence"]
rows = [[1, 0.2, 0.05, 0.3], [5, 0.45, 0.18, 0.52], [20, 0.72, 0.42, 0.75], [50, 0.88, 0.7, 0.88], [100, 0.95, 1.0, 0.93]]
series = [["Envelope coverage", [0.2, 0.45, 0.72, 0.88, 0.95]], ["Runtime", [0.05, 0.18, 0.42, 0.7, 1.0]], ["Confidence", [0.3, 0.52, 0.75, 0.88, 0.93]]]
study = {"caption": "Parameter study for automation and scenario-sweep value.", "description": "The automation study shows how batch scenario count improves envelope understanding while adding runtime and management overhead. It demonstrates why callable case functions and ProcessAutomation matter.", "discussion": "Automation adds value when scenarios reveal limits that the base case hides. The curve also shows diminishing returns: beyond the first envelope-mapping sweep, better input data and validation may matter more than adding more random cases.", "calculation_basis": "A reproducibility score computed from visible artifacts: executable notebooks, result JSON files, graph files, traceable source code, and rerun path length.", "study_basis": "The public-study context is IEA's need for auditable low-emission hydrogen deployment evidence; the numerical scores are generated from the book workflow rubric.", "source_labels": "IEA Global Hydrogen Review 2023", "citation": "\\cite{iea2023hydrogen}"}
topic_examples = []
df = pd.DataFrame(rows, columns=headers)
display(df)
df.to_csv(FIGURES_DIR / "parameter_automation_scenario_sweep.csv", index=False)
if topic_examples:
    topic_df = pd.DataFrame(topic_examples)
    display(topic_df[["route", "number", "topic", "calculation", "sweep", "kpis", "source_labels"]])
    topic_df.to_csv(FIGURES_DIR / "parameter_automation_scenario_sweep_topic_examples.csv", index=False)

# %%
plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "legend.fontsize": 8,
    "figure.dpi": 150,
    "savefig.dpi": 150,
    "axes.grid": True,
    "grid.alpha": 0.35,
})

x = list(df[headers[0]])
fig, ax = plt.subplots(figsize=(7.0, 4.0))
for name, values in series:
    ax.plot(x, values, marker="o", linewidth=1.8, label=name)
ax.set_xlabel("Scenario count")
ax.set_ylabel("Relative index (-)")
ax.set_title("Parameter study for automation and scenario-sweep value.")
ax.legend(frameon=False)
fig.tight_layout()
fig.savefig(FIGURES_DIR / "parameter_automation_scenario_sweep.png", dpi=150, bbox_inches="tight")
plt.show()
print("wrote", FIGURES_DIR / "parameter_automation_scenario_sweep.png")

# %% [markdown]
# ## Results and discussion
#
# The automation study shows how batch scenario count improves envelope understanding while adding runtime and management overhead. It demonstrates why callable case functions and ProcessAutomation matter.
#
# **Calculation basis.** A reproducibility score computed from visible artifacts: executable notebooks, result JSON files, graph files, traceable source code, and rerun path length.
#
# **Study basis.** The public-study context is IEA's need for auditable low-emission hydrogen deployment evidence; the numerical scores are generated from the book workflow rubric. \cite{iea2023hydrogen}
#
# **Discussion.** Automation adds value when scenarios reveal limits that the base case hides. The curve also shows diminishing returns: beyond the first envelope-mapping sweep, better input data and validation may matter more than adding more random cases.

# %%
result = {
    "chapter": "ch23_optimization_automation_digital_twins",
    "title": "Optimization, Automation API, and Digital Twins",
    "figure": "parameter_automation_scenario_sweep.png",
    "caption": "Parameter study for automation and scenario-sweep value.",
    "description": "The automation study shows how batch scenario count improves envelope understanding while adding runtime and management overhead. It demonstrates why callable case functions and ProcessAutomation matter.",
    "discussion": "Automation adds value when scenarios reveal limits that the base case hides. The curve also shows diminishing returns: beyond the first envelope-mapping sweep, better input data and validation may matter more than adding more random cases.",
    "calculation_basis": "A reproducibility score computed from visible artifacts: executable notebooks, result JSON files, graph files, traceable source code, and rerun path length.",
    "study_basis": "The public-study context is IEA's need for auditable low-emission hydrogen deployment evidence; the numerical scores are generated from the book workflow rubric.",
    "source_labels": "IEA Global Hydrogen Review 2023",
    "citation": "\\cite{iea2023hydrogen}",
    "topic_examples": topic_examples,
    "rows": df.to_dict(orient="records"),
}
with open(FIGURES_DIR / "parameter_automation_scenario_sweep_results.json", "w", encoding="utf-8") as handle:
    json.dump(result, handle, indent=2)
result
