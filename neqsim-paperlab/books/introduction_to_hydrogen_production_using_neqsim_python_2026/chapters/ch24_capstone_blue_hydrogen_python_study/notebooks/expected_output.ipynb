# %% [markdown]
# # Parameter study for Capstone A: Blue H2 Plant Python Study
#
#     This notebook regenerates the parameter-study table and figure embedded in the
#     chapter. It is intentionally lightweight so PaperLab can refresh the visible
#     results while the full companion notebook remains available for broader
#     branch-specific NeqSim workflows.

# %%
from pathlib import Path
import json

import pandas as pd
import matplotlib
matplotlib.use("Agg")
import matplotlib.pyplot as plt

NOTEBOOK_DIR = Path(globals().get("__vsc_ipynb_file__", "expected_output.ipynb")).resolve().parent
FIGURES_DIR = NOTEBOOK_DIR.parent / "figures"
FIGURES_DIR.mkdir(exist_ok=True)

headers = ["Case", "H2 product index", "Residual CI index", "Total energy index"]
rows = [["Base 90%", 1.0, 0.18, 1.0], ["High capture", 0.98, 0.1, 1.08], ["Low S/C", 1.04, 0.22, 0.94], ["High pressure export", 0.99, 0.18, 1.12]]
series = [["H2 product", [1.0, 0.98, 1.04, 0.99]], ["Residual CI", [0.18, 0.1, 0.22, 0.18]], ["Energy", [1.0, 1.08, 0.94, 1.12]]]
study = {"caption": "Parameter study for blue-H2 capstone acceptance criteria.", "description": "The blue capstone study compares capture target cases against residual carbon intensity, hydrogen product index, and total energy index.", "discussion": "The capstone result makes acceptance criteria explicit. The best carbon case is not automatically the best energy case, and a process change that increases hydrogen production may worsen residual carbon intensity. This is why capstone notebooks need pass/warn/fail criteria, not only KPIs.", "calculation_basis": "Stoichiometric SMR/ATR/POX/WGS balances, equilibrium or route-builder sweeps, PSA recovery accounting, and CO2-capture mass-balance indices.", "study_basis": "IEA hydrogen route context plus process-design and gas-purification references set the screening ranges and interpretation limits.", "source_labels": "IEA Global Hydrogen Review 2023, Chemical engineering design reference, Gas purification reference, GPSA engineering data reference", "citation": "\\cite{iea2023hydrogen,towler2013chemical,kohl1997,gpsa2012}"}
topic_examples = []
df = pd.DataFrame(rows, columns=headers)
display(df)
df.to_csv(FIGURES_DIR / "parameter_blue_capstone_acceptance.csv", index=False)
if topic_examples:
    topic_df = pd.DataFrame(topic_examples)
    display(topic_df[["route", "number", "topic", "calculation", "sweep", "kpis", "source_labels"]])
    topic_df.to_csv(FIGURES_DIR / "parameter_blue_capstone_acceptance_topic_examples.csv", index=False)

# %%
plt.rcParams.update({
    "font.family": "DejaVu Sans",
    "font.size": 9,
    "axes.titlesize": 10,
    "axes.labelsize": 9,
    "legend.fontsize": 8,
    "figure.dpi": 150,
    "savefig.dpi": 150,
    "axes.grid": True,
    "grid.alpha": 0.35,
})

x = list(df[headers[0]])
fig, ax = plt.subplots(figsize=(7.0, 4.0))
for name, values in series:
    ax.plot(x, values, marker="o", linewidth=1.8, label=name)
ax.set_xlabel("Blue-H2 capstone case")
ax.set_ylabel("Relative index (-)")
ax.set_title("Parameter study for blue-H2 capstone acceptance criteria.")
ax.legend(frameon=False)
fig.tight_layout()
fig.savefig(FIGURES_DIR / "parameter_blue_capstone_acceptance.png", dpi=150, bbox_inches="tight")
plt.show()
print("wrote", FIGURES_DIR / "parameter_blue_capstone_acceptance.png")

# %% [markdown]
# ## Results and discussion
#
# The blue capstone study compares capture target cases against residual carbon intensity, hydrogen product index, and total energy index.
#
# **Calculation basis.** Stoichiometric SMR/ATR/POX/WGS balances, equilibrium or route-builder sweeps, PSA recovery accounting, and CO2-capture mass-balance indices.
#
# **Study basis.** IEA hydrogen route context plus process-design and gas-purification references set the screening ranges and interpretation limits. \cite{iea2023hydrogen,towler2013chemical,kohl1997,gpsa2012}
#
# **Discussion.** The capstone result makes acceptance criteria explicit. The best carbon case is not automatically the best energy case, and a process change that increases hydrogen production may worsen residual carbon intensity. This is why capstone notebooks need pass/warn/fail criteria, not only KPIs.

# %%
result = {
    "chapter": "ch24_capstone_blue_hydrogen_python_study",
    "title": "Capstone A: Blue H2 Plant Python Study",
    "figure": "parameter_blue_capstone_acceptance.png",
    "caption": "Parameter study for blue-H2 capstone acceptance criteria.",
    "description": "The blue capstone study compares capture target cases against residual carbon intensity, hydrogen product index, and total energy index.",
    "discussion": "The capstone result makes acceptance criteria explicit. The best carbon case is not automatically the best energy case, and a process change that increases hydrogen production may worsen residual carbon intensity. This is why capstone notebooks need pass/warn/fail criteria, not only KPIs.",
    "calculation_basis": "Stoichiometric SMR/ATR/POX/WGS balances, equilibrium or route-builder sweeps, PSA recovery accounting, and CO2-capture mass-balance indices.",
    "study_basis": "IEA hydrogen route context plus process-design and gas-purification references set the screening ranges and interpretation limits.",
    "source_labels": "IEA Global Hydrogen Review 2023, Chemical engineering design reference, Gas purification reference, GPSA engineering data reference",
    "citation": "\\cite{iea2023hydrogen,towler2013chemical,kohl1997,gpsa2012}",
    "topic_examples": topic_examples,
    "rows": df.to_dict(orient="records"),
}
with open(FIGURES_DIR / "parameter_blue_capstone_acceptance_results.json", "w", encoding="utf-8") as handle:
    json.dump(result, handle, indent=2)
result
